# %%
import pandas as   pd

# %% [markdown]
# #### Preprocessing

# %%
data = pd.read_csv("../../data/genedata.csv")
data
# Out:
#       id  class      f1      f2       f3       f4       f5       f6       f7  \
# 0      1      5  4.8778  4.4118   9.0690  10.0966  11.1664  10.2457   8.2541
# 1      2      4  8.9505  2.7079  10.0899   6.5899   9.5933   8.3250   9.9028
# 2      3      5  4.7239  3.7181   9.2404  10.1070  10.0589   9.5977   8.3794
# 3      4      5  7.6797  4.1321   9.3522   9.3646  10.2057   9.4130   8.8524
# 4      5      1  6.1541  5.9960   9.5418   8.9614   9.6077   9.3430   9.9071
# 5      6      5  6.4047  6.0595   9.0935  10.2877  10.6286  10.4826   8.5257
# 6      7      2  5.4232  7.4721   8.6147   9.7714  10.3270   8.1019   8.8122
# 7      8      5  6.6371  9.4040   9.0068  11.0574  10.4056  10.3253   8.7740
# 8      9      1  8.8400  3.9944   9.3881   8.4041  10.0069   9.1963  11.2796
# 9     10      5  3.4303  7.7603  10.0027  11.0552  10.3748   9.6930   8.4123
# 10    11      1  7.1794  4.2796   8.6448   9.8059  10.8064   8.0423  10.7845
# ...
